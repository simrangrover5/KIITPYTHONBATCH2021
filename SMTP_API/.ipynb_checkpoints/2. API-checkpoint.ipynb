# %%
import requests

# %%
key = "e9034b1eee3034977886c9f275b27127"
city = input("\n Enter city name --> ")
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={key}"
resp = requests.get(url)
if resp.status_code == 200:
    print(resp.json())
else:
    print("\n URL IS NOT CORRECT OR SERVER IS NOT RESPONDING")
# Out:
#  Enter city name --> jaipur
# {'coord': {'lon': 75.8167, 'lat': 26.9167}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 299.77, 'feels_like': 299.77, 'temp_min': 299.77, 'temp_max': 299.77, 'pressure': 997, 'humidity': 89}, 'visibility': 2500, 'wind': {'speed': 2.57, 'deg': 300}, 'rain': {'1h': 0.65}, 'clouds': {'all': 75}, 'dt': 1627311896, 'sys': {'type': 1, 'id': 9170, 'country': 'IN', 'sunrise': 1627258668, 'sunset': 1627307305}, 'timezone': 19800, 'id': 1269515, 'name': 'Jaipur', 'cod': 200}

# %%
data = resp.json()

# %%
desc = data['weather'][0]['description']
temp = round(data['main']['temp'] - 273.19, 2)
temp_min = round(data['main']['temp_min'] - 273.19, 2)
temp_max = round(data['main']['temp_max'] - 273.19, 2)
humid = round(data['main']['humidity'])
country = data['sys']['country']
icon = data['weather'][0]['icon']

# %%
data['weather'][0]['icon']
# Out:
# '10n'

# %%
def get_weather(city):
    key = "e9034b1eee3034977886c9f275b27127"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={key}"
    resp = requests.get(url)
    if resp.status_code == 200:
        data = resp.json()
        desc = data['weather'][0]['description']
        temp = round(data['main']['temp'] - 273.19, 2)
        temp_min = round(data['main']['temp_min'] - 273.19, 2)
        temp_max = round(data['main']['temp_max'] - 273.19, 2)
        humid = round(data['main']['humidity'])
        country = data['sys']['country']
        icon = data['weather'][0]['icon']
        value = [desc, temp, temp_min, temp_max, humid, country]
        name = ['Description', 'Temperature', 'Temperature_Min', 'Temperature_Max',
               'Humidity', 'Country']
        for x, y in zip(name, value):
            print(f"{x} --> {y}".center(80))
        url1 =f"http://openweathermap.org/img/w/{icon}.png" 
        resp = requests.get(url1)
        if resp.status_code == 200:
            with open(f"{city}.png", 'wb') as file:
                file.write(resp.content)
            plt.figure(figsize=(1,1))
            img = plt.imread(f"{city}.png")
            plt.imshow(img)
            plt.axis("off")  # to not show the lines/spines and do disable the ticks
            plt.show()
        else:
            print("Incorrect Image Url")
    else:
        print("\n URL IS NOT CORRECT OR SERVER IS NOT RESPONDING")

city = input("\n Enter city name --> ")
get_weather(city)
# Out:
#  Enter city name --> london
#                         Description --> scattered clouds
#                              Temperature --> 24.11
#                            Temperature_Min --> 21.46
#                            Temperature_Max --> 27.01
#                                 Humidity --> 65
#                                  Country --> GB

# %%
url = "http://openweathermap.org/img/w/10n.png" 
resp = requests.get(url)
with open("jaipur.png", 'wb') as file:
    file.write(resp.content)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E08D-DAD9
#
#  Directory of C:\batches\online_batch\KITBatch3pm\SMTP_API
#
# 26-07-2021  20:49    <DIR>          .
# 26-07-2021  20:49    <DIR>          ..
# 26-07-2021  20:15    <DIR>          .ipynb_checkpoints
# 26-07-2021  20:49             5,223 2. API.ipynb
# 24-07-2021  13:01            12,186 API.ipynb
# 26-07-2021  20:49             3,801 jaipur.png
# 24-07-2021  11:28            19,374 SMTP.ipynb
#                4 File(s)         40,584 bytes
#                3 Dir(s)  36,997,492,736 bytes free

# %%
from IPython.display import Image

# %%
Image("jaipur.png")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(1,1))
img = plt.imread("jaipur.png")
plt.imshow(img)
plt.axis("off")  # to not show the lines/spines and do disable the ticks
plt.show()

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E08D-DAD9
#
#  Directory of C:\batches\online_batch\KITBatch3pm\SMTP_API
#
# 26-07-2021  20:55    <DIR>          .
# 26-07-2021  20:55    <DIR>          ..
# 26-07-2021  20:15    <DIR>          .ipynb_checkpoints
# 26-07-2021  20:55            17,087 2. API.ipynb
# 24-07-2021  13:01            12,186 API.ipynb
# 26-07-2021  20:49             3,801 jaipur.png
# 24-07-2021  11:28            19,374 SMTP.ipynb
#                4 File(s)         52,448 bytes
#                3 Dir(s)  36,989,984,768 bytes free

# %%
import requests

movie = input("Movie --> ")
url = f"https://imdb-internet-movie-database-unofficial.p.rapidapi.com/film/{movie}"

headers = {
    'x-rapidapi-key': "a88ff77402mshb59de67584167e6p113a98jsncad39a9d4c55",
    'x-rapidapi-host': "imdb-internet-movie-database-unofficial.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# Movie --> jab we met
# {"id":"tt1093370","title":"Jab We Met\u00a0","year":"2007","length":"2h 18min","rating":"7.9","rating_votes":"44260","poster":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYmIzYmY4MGItM2I4YS00OWZhLWFmMzQtYzI2MWY1MmM3NGU1XkEyXkFqcGdeQXVyNjQ2MjQ5NzM@.jpg","plot":"A depressed wealthy businessman finds his life changing after he meets a spunky and care-free young woman.","trailer":{"id":"vi3972250393","link":"https:\/\/www.imdb.com\/videoplayer\/vi3972250393"},"cast":[{"actor":"Shahid Kapoor","actor_id":"nm1372788","character":"Aditya D. Kashyap"},{"actor":"Kareena Kapoor","actor_id":"nm0004626","character":"Geet Kaur Dhillon"},{"actor":"Tarun Arora","actor_id":"nm1595577","character":"Anshuman"},{"actor":"Dara Singh","actor_id":"nm0802107","character":"Dadaji"},{"actor":"Pavan Malhotra","actor_id":"nm0539497","character":"Geet's Chacha (as Pawan Malhotra)"},{"actor":"Kamal Tiwari","actor_id":"nm1033153","character":""},{"actor":"Kiran Juneja","actor_id":"nm1185265","character":"Mrs. Dhillon"},{"actor":"Divya Shah","actor_id":"nm2275659","character":"Mrs. Khanna"},{"actor":"Saumya Tandon","actor_id":"nm2777374","character":"Roop Kaur Dhillon"},{"actor":"Nihar Thakkar","actor_id":"nm3130252","character":"Raghav"},{"actor":"Manushka Khisty","actor_id":"nm3129389","character":"Meher"},{"actor":"F.J. Jussawala","actor_id":"nm3129206","character":"Mother's lawyer"},{"actor":"Vishal Om Prakash","actor_id":"nm2119028","character":"Aditya's lawyer (as Vishal Sharma)"},{"actor":"Rohini Sahni","actor_id":"nm3130122","character":"Bride"},{"actor":"Deepak Sharma","actor_id":"nm3128877","character":"Groom"}],"technical_specs":[["Runtime","2 hr 18 min (138 min)"],["Sound Mix","Dolby Digital | Stereo (Song Recording and Mixing Engineer)"],["Color","Color"],["Aspect Ratio","2.35 : 1"],["Camera","Panavision Panaflex Platinum, Panavision Primo Lenses"],["Laboratory","Adlabs Films Pvt. Ltd., Mumbai, India"],["Film Length","3,957 m (Portugal, 35 mm)"],["Negative Format","35 mm (Kodak)"],["Cinematographic Process","Digital Intermediate (master format) <br> Super 35 (source format)"],["Printed Film Format","35 mm (anamorphic)"]]}

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
client_id='INFLUOTLIPTCNRIGX2DSHGJ1FSYNO5ZOQZIAQFTIVNV4LIZA',
client_secret='AZOM4LC43F0ICM2FXIS0FGZF1QSFR4VYOOFJQQSTX5VXBEB1',
v='20180323',
ll='40.7243,-74.0018',
query='coffee',
limit=10
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '60fed9eba1aa2362c6b9eca1'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'suggestedRadius': 600,
#   'headerLocation': 'SoHo',
#   'headerFullLocation': 'SoHo, New York',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'coffee',
#   'totalResults': 62,
#   'suggestedBounds': {'ne': {'lat': 40.726551549999996,
#     'lng': -73.99907671174947},
#    'sw': {'lat': 40.72266745, 'lng': -74.00485148991669}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '573498df498e6df2eb8b36a7',
#        'name': 'La Colombe Torrefaction',
#        'contact': {},
#        'location': {'address': '154 Prince St',
#         'crossStreet': 'btwn W Broadway & Thompson',
#         'lat': 40.72581964106336,
#         'lng': -74.00119185447693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72581964106336,
#           'lng': -74.00119185447693},
#          {'label': 'entrance', 'lat': 40.72582, 'lng': -74.001153}],
#         'distance': 176,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['154 Prince St (btwn W Broadway & Thompson)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '2075401',
#         'url': 'https://www.seamless.com/menu/la-colombe-154-prince-street-new-york/2075401?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2075401',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-573498df498e6df2eb8b36a7-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '45e98bacf964a52080431fe3',
#        'name': 'MarieBelle',
#        'contact': {},
#        'location': {'address': '484 Broome St',
#         'crossStreet': 'btwn W Broadway & Wooster St',
#         'lat': 40.72310132633388,
#         'lng': -74.00247749675871,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72310132633388,
#           'lng': -74.00247749675871}],
#         'distance': 145,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['484 Broome St (btwn W Broadway & Wooster St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '488596',
#         'url': 'https://www.seamless.com/menu/marie-belle-new-york-484-broome-st-new-york/488596?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=488596',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '81170724'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-45e98bacf964a52080431fe3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56cb2d99498eb620bee31423',
#        'name': 'Rapha NYC',
#        'contact': {},
#        'location': {'address': '159 Prince St',
#         'lat': 40.72596825325445,
#         'lng': -74.00122621589483,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72596825325445,
#           'lng': -74.00122621589483}],
#         'distance': 191,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['159 Prince St',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-56cb2d99498eb620bee31423-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f3ecdaa960de027c22a9e80',
#        'name': 'Felix Roasting Co.',
#        'contact': {},
#        'location': {'address': '104 Greene St',
#         'lat': 40.72441300724409,
#         'lng': -73.99970054626465,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72441300724409,
#           'lng': -73.99970054626465}],
#         'distance': 177,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['104 Greene St',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '2473483',
#         'url': 'https://www.seamless.com/menu/felix-roasting-co-104-greene-st-new-york/2473483?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2473483',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-5f3ecdaa960de027c22a9e80-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ab0af5498e13bffddb8d96',
#        'name': 'Pi Greek Bakerie',
#        'contact': {},
#        'location': {'address': '512 Broome St',
#         'crossStreet': 'at Thompson St',
#         'lat': 40.723515651165286,
#         'lng': -74.00344360363695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.723515651165286,
#           'lng': -74.00344360363695},
#          {'label': 'entrance', 'lat': 40.72359, 'lng': -74.003291}],
#         'distance': 163,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['512 Broome St (at Thompson St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '304388',
#         'url': 'https://www.seamless.com/menu/pi-bakerie-and-eaterie-512-broome-st-new-york/304388?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304388',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '90381820'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-53ab0af5498e13bffddb8d96-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f36418ee4b017ad79b8e8a2',
#        'name': 'Georgetown Cupcake',
#        'contact': {},
#        'location': {'address': '111 Mercer St',
#         'crossStreet': 'btwn Spring St & Prince St',
#         'lat': 40.72373721901756,
#         'lng': -73.99933920166615,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.72373721901756,
#           'lng': -73.99933920166615},
#          {'label': 'entrance', 'lat': 40.723849, 'lng': -73.999357}],
#         'distance': 216,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['111 Mercer St (btwn Spring St & Prince St)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1bc941735',
#          'name': 'Cupcake Shop',
#          'pluralName': 'Cupcake Shops',
#          'shortName': 'Cupcakes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63138710'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4f36418ee4b017ad79b8e8a2-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a942a25f964a520972020e3',
#        'name': 'Ground Support',
#        'contact': {},
#        'location': {'address': '399 W Broadway',
#         'crossStreet': 'btwn Spring & Broome St',
#         'lat': 40.724292163165124,
#         'lng': -74.00212009222999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.724292163165124,
#           'lng': -74.00212009222999},
#          {'label': 'entrance', 'lat': 40.724281, 'lng': -74.002011}],
#         'distance': 27,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['399 W Broadway (btwn Spring & Broome St)',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '2078210',
#         'url': 'https://www.seamless.com/menu/ground-support-cafe-399-west-broadway-new-york/2078210?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2078210',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '38325963'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4a942a25f964a520972020e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '571a6c25498e64cbcc8b3b6c',
#        'name': 'JOE & THE JUICE',
#        'contact': {},
#        'location': {'address': '161 Prince St',
#         'lat': 40.725983351525194,
#         'lng': -74.00129767836906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.725983351525194,
#           'lng': -74.00129767836906}],
#         'distance': 192,
#         'postalCode': '10012',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['161 Prince St',
#          'New York, NY 10012',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-571a6c25498e64cbcc8b3b6c-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50e6eae5e4b06de013260a31',
#        'name': 'Bar Ciccio Alimentari',
#        'contact': {},
#        'location': {'address': '190 Avenue of the Americas',
#         'crossStreet': 'Spring St',
#         'lat': 40.726375,
#         'lng': -74.003369,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.726375,
#           'lng': -74.003369},
#          {'label': 'entrance', 'lat': 40.726325, 'lng': -74.003451}],
#         'distance': 266,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['190 Avenue of the Americas (Spring St)',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '2072976',
#         'url': 'https://www.seamless.com/menu/ciccio-bar--alimentari-190-6th-avenue-new-york/2072976?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2072976',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-50e6eae5e4b06de013260a31-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cbf6a44da2e00002c46c6b3',
#        'name': 'Now or Never',
#        'contact': {},
#        'location': {'address': '30 Grand St',
#         'lat': 40.722844,
#         'lng': -74.004589,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.722844,
#           'lng': -74.004589}],
#         'distance': 285,
#         'postalCode': '10013',
#         'cc': 'US',
#         'city': 'New York',
#         'state': 'NY',
#         'country': 'United States',
#         'formattedAddress': ['30 Grand St',
#          'New York, NY 10013',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'delivery': {'id': '2088541',
#         'url': 'https://www.seamless.com/menu/now-or-never-30-grand-street-new-york/2088541?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2088541',
#         'provider': {'name': 'seamless',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_seamless_20180129.png'}}},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 1,
#         'summary': 'One other person is here',
#         'groups': [{'type': 'others',
#           'name': 'Other people here',
#           'count': 1,
#           'items': []}]}},
#       'referralId': 'e-0-5cbf6a44da2e00002c46c6b3-9'}]}]}}
